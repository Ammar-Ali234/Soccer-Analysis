# %% [markdown]
# # Step1: Upload all the Files into this Environment

# %% [markdown]
# # Step2: Install the requirements of the Project find it in requirements.txt and past each of them individually in the same as i did below.

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.9/906.9 kB 14.4 MB/s eta 0:00:00
# ...

# %%
# !pip install filterpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110458 sha256=e201906359701f2d2738a63fb62b6ab7aa9a35eb15446f23f8c30ce2d8fa9c91
#   Stored in directory: /root/.cache/pip/wheels/12/dc/3c/e12983eac132d00f82a20c6cbe7b42ce6e96190ef8fa2d15e1
# Successfully built filterpy
# ...

# %%
# !pip install scikit-image

# %% [markdown]
# # You should have to see the same things as i am seeing which will make sure that all files are in the environment

# %%
ls
# Out:
# Distance_calculation.py  heatmap.py  main.py  sample_data/  sort.py

# %% [markdown]
# # before running the below cell open the main.py by double clicking and replace the path of the video with your one > (hint line number 14 of main.py)

# %%
# !python main.py
# Out:
# 0: 480x640 3 persons, 11 cars, 2 trucks, 1 traffic light, 1 sports ball, 1 baseball glove, 221.2ms
# Speed: 9.5ms preprocess, 221.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 10 cars, 2 trucks, 1 traffic light, 2 sports balls, 223.9ms
# Speed: 4.2ms preprocess, 223.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 12 cars, 1 truck, 1 traffic light, 2 sports balls, 1 baseball glove, 195.8ms
# Speed: 3.8ms preprocess, 195.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 9 cars, 2 trucks, 1 traffic light, 2 sports balls, 1 baseball glove, 324.8ms
# Speed: 4.2ms preprocess, 324.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 14 cars, 1 truck, 2 sports balls, 325.8ms
# Speed: 10.7ms preprocess, 325.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# ...

# %% [markdown]
# # Wait the Model will process and all the files will be in you environment after this cell successfully runs.
